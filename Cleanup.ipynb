# %% [markdown]
# # Pandas Clean-up

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Read in CSV and display a few rows
airports = pd.read_csv('Resources/us-airports.csv')
airports.head()
# Out:
#           id        ident                 type  \
# 0  #meta +id  #meta +code  #loc +airport +type
# 1       3632         KLAX        large_airport
# 2       3754         KORD        large_airport
# 3       3622         KJFK        large_airport
# 4       3384         KATL        large_airport
#
#                                                name latitude_deg  \
# 0                               #loc +airport +name    #geo +lat
# 1                 Los Angeles International Airport    33.942501
# 2              Chicago O'Hare International Airport      41.9786
# 3              John F Kennedy International Airport    40.639447
# 4  Hartsfield Jackson Atlanta International Airport      33.6367
#
#   longitude_deg         elevation_ft                 continent  \
# 0     #geo +lon  #geo +elevation +ft  #region +continent +code
# 1   -118.407997                  125                       NaN
# 2      -87.9048                  680                       NaN
# 3    -73.779317                   13                       NaN
# 4    -84.428101                 1026                       NaN
#
#      country_name           iso_country  ...              municipality  \
# 0  #country +name  #country +code +iso2  ...  #loc +municipality +name
# 1   United States                    US  ...               Los Angeles
# 2   United States                    US  ...                   Chicago
# 3   United States                    US  ...                  New York
# 4   United States                    US  ...                   Atlanta
#
#     scheduled_service                  gps_code                  iata_code  \
# 0  #status +scheduled  #loc +airport +code +gps  #loc +airport +code +iata
# 1                   1                      KLAX                        LAX
# 2                   1                      KORD                        ORD
# 3                   1                      KJFK                        JFK
# 4                   1                      KATL                        ATL
#
#                    local_code  \
# 0  #loc +airport +code +local
# 1                         LAX
# 2                         ORD
# 3                         JFK
# 4                         ATL
#
#                                            home_link  \
# 0                                #meta +url +airport
# 1                            https://www.flylax.com/
# 2  https://www.flychicago.com/ohare/home/pages/de...
# 3                        https://www.jfkairport.com/
# 4                    http://www.atlanta-airport.com/
#
#                                       wikipedia_link  \
# 0                              #meta +url +wikipedia
# 1  https://en.wikipedia.org/wiki/Los_Angeles_Inte...
# 2  https://en.wikipedia.org/wiki/O'Hare_Internati...
# 3  https://en.wikipedia.org/wiki/John_F._Kennedy_...
# 4  https://en.wikipedia.org/wiki/Hartsfield–Jacks...
#
#                                             keywords         score  \
# 0                                    #meta +keywords  #meta +score
# 1                                        Tom Bradley       1335475
# 2                                 CHI, Orchard Place       1503175
# 3  Manhattan, New York City, NYC, Idlewild, IDL, ...       1052075
# 4                                                NaN       2002475
#
#                 last_updated
# 0             #date +updated
# 1  2023-12-21T12:31:02+00:00
# 2  2024-03-09T23:28:49+00:00
# 3  2022-10-18T18:49:55+00:00
# 4  2018-09-19T14:50:01+00:00
#
# [5 rows x 23 columns]

# %%
airports.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'country_name', 'iso_country',
#        'region_name', 'iso_region', 'local_region', 'municipality',
#        'scheduled_service', 'gps_code', 'iata_code', 'local_code', 'home_link',
#        'wikipedia_link', 'keywords', 'score', 'last_updated'],
#       dtype='object')

# %%
# Select columns and create new dataframe
airport_columns_df = pd.DataFrame(airports[['iata_code', 'type', 'name', 'latitude_deg', 'longitude_deg',
       'elevation_ft','region_name', 'local_region']])
airport_columns_df.head()
# Out:
#                    iata_code                 type  \
# 0  #loc +airport +code +iata  #loc +airport +type
# 1                        LAX        large_airport
# 2                        ORD        large_airport
# 3                        JFK        large_airport
# 4                        ATL        large_airport
#
#                                                name latitude_deg  \
# 0                               #loc +airport +name    #geo +lat
# 1                 Los Angeles International Airport    33.942501
# 2              Chicago O'Hare International Airport      41.9786
# 3              John F Kennedy International Airport    40.639447
# 4  Hartsfield Jackson Atlanta International Airport      33.6367
#
#   longitude_deg         elevation_ft  region_name        local_region
# 0     #geo +lon  #geo +elevation +ft  #adm1 +name  #adm1 +code +local
# 1   -118.407997                  125   California                  CA
# 2      -87.9048                  680     Illinois                  IL
# 3    -73.779317                   13     New York                  NY
# 4    -84.428101                 1026      Georgia                  GA

# %%
# Drop description row, leave headers
airports_df = airport_columns_df.drop(0).reset_index(drop=True)
airports_df.head()
# Out:
#   iata_code           type                                              name  \
# 0       LAX  large_airport                 Los Angeles International Airport
# 1       ORD  large_airport              Chicago O'Hare International Airport
# 2       JFK  large_airport              John F Kennedy International Airport
# 3       ATL  large_airport  Hartsfield Jackson Atlanta International Airport
# 4       SFO  large_airport               San Francisco International Airport
#
#         latitude_deg longitude_deg elevation_ft region_name local_region
# 0          33.942501   -118.407997          125  California           CA
# 1            41.9786      -87.9048          680    Illinois           IL
# 2          40.639447    -73.779317           13    New York           NY
# 3            33.6367    -84.428101         1026     Georgia           GA
# 4  37.61899948120117      -122.375           13  California           CA

# %%
# Check types of airports included
airports_df['type'].value_counts()
# Out:
# type
# small_airport     15018
# heliport           7935
# closed             6484
# medium_airport      806
# seaplane_base       631
# large_airport        67
# balloonport          29
# Name: count, dtype: int64

# %%
# Remove erroneous types
erroneous = ((airports_df['type'] == 'balloonport') | (airports_df['type'] == 'closed') | \
            (airports_df['type'] == 'seaplane_base') | (airports_df['type'] == 'heliport') | \
            airports_df['iata_code'].isna())

cleaned_df = airports_df[~erroneous].reset_index(drop=True)
cleaned_df.head()
# Out:
#   iata_code           type                                              name  \
# 0       LAX  large_airport                 Los Angeles International Airport
# 1       ORD  large_airport              Chicago O'Hare International Airport
# 2       JFK  large_airport              John F Kennedy International Airport
# 3       ATL  large_airport  Hartsfield Jackson Atlanta International Airport
# 4       SFO  large_airport               San Francisco International Airport
#
#         latitude_deg longitude_deg elevation_ft region_name local_region
# 0          33.942501   -118.407997          125  California           CA
# 1            41.9786      -87.9048          680    Illinois           IL
# 2          40.639447    -73.779317           13    New York           NY
# 3            33.6367    -84.428101         1026     Georgia           GA
# 4  37.61899948120117      -122.375           13  California           CA

# %%
# Verify types
cleaned_df['type'].value_counts()
# Out:
# type
# small_airport     1047
# medium_airport     767
# large_airport       66
# Name: count, dtype: int64

# %%
cleaned_df['region_name'].value_counts()
# Out:
# region_name
# Alaska                  268
# California              142
# Texas                   115
# Florida                  75
# Michigan                 48
# Washington               47
# Arizona                  46
# New York                 43
# Wisconsin                43
# Iowa                     42
# Oklahoma                 41
# Pennsylvania             40
# Illinois                 39
# Colorado                 37
# Georgia                  37
# Minnesota                36
# Kansas                   36
# Oregon                   36
# Indiana                  35
# Ohio                     35
# North Carolina           34
# Arkansas                 32
# Virginia                 32
# South Carolina           31
# Nebraska                 31
# Nevada                   29
# New Mexico               29
# Missouri                 28
# Wyoming                  28
# Utah                     28
# Alabama                  27
# Mississippi              27
# Montana                  26
# Tennessee                25
# Louisiana                22
# Hawaii                   21
# Massachusetts            20
# Maine                    19
# South Dakota             18
# Idaho                    18
# Kentucky                 17
# Maryland                 16
# New Jersey               16
# North Dakota             15
# West Virginia            14
# New Hampshire            12
# Vermont                   7
# Connecticut               7
# Rhode Island              6
# Delaware                  3
# District of Columbia      1
# Name: count, dtype: int64

# %%
cleaned_df.tail()
# Out:
#      iata_code           type                  name     latitude_deg  \
# 1875       UMT  small_airport         Umiat Airport      69.37110138
# 1876       UWA  small_airport          Ware Airport  42.282001495361
# 1877       EAN  small_airport       Phifer Airfield          42.0555
# 1878       WSM  small_airport       Wiseman Airport    67.4046020508
# 1879       LGF  small_airport  Laguna Army Airfield      32.86000061
#
#          longitude_deg elevation_ft    region_name local_region
# 1875      -152.1360016          267         Alaska           AK
# 1876  -72.214797973633          483  Massachusetts           MA
# 1877       -104.929001         4776        Wyoming           WY
# 1878    -150.123001099         1180         Alaska           AK
# 1879      -114.3970032          433        Arizona           AZ

# %%
#exporting to csv
cleaned_df.to_csv('Resources/us-airports-cleaned.csv', index=False)

# %%
erroneous2 = ((airports_df['type'] == 'balloonport') | (airports_df['type'] == 'closed') | \
            (airports_df['type'] == 'seaplane_base') | (airports_df['type'] == 'heliport') | \
            (airports_df['type'] == 'small_airport') | (airports_df['type'] == 'medium_airport') | \
            (airports_df['iata_code'].isna()))
cleaned_df2 = airports_df[~erroneous2]
cleaned_df2['type'].value_counts()
# Out:
# type
# large_airport    66
# Name: count, dtype: int64

# %%
# creating data source with just large airports and their coordinates
large_airports_lat_long = pd.DataFrame(cleaned_df2[['iata_code','name', 'latitude_deg', 'longitude_deg']])
large_airports_lat_long.head()
# Out:
#   iata_code                                              name  \
# 0       LAX                 Los Angeles International Airport
# 1       ORD              Chicago O'Hare International Airport
# 2       JFK              John F Kennedy International Airport
# 3       ATL  Hartsfield Jackson Atlanta International Airport
# 4       SFO               San Francisco International Airport
#
#         latitude_deg longitude_deg
# 0          33.942501   -118.407997
# 1            41.9786      -87.9048
# 2          40.639447    -73.779317
# 3            33.6367    -84.428101
# 4  37.61899948120117      -122.375

# %%
#exporting to csv
large_airports_lat_long.to_csv('Resources/large_airports_lat_long.csv', index=False)
